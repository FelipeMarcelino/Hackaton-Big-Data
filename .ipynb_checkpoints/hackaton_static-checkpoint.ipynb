# %%
#imports
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import sys
import seaborn as sns
sns.set_style('darkgrid')

import xgboost
from sklearn.model_selection import train_test_split,cross_val_score, KFold
from sklearn.metrics import accuracy_score,mean_squared_error
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.metrics import mean_squared_error
from sklearn import linear_model
from sklearn import tree
from xgboost import plot_importance
from sklearn.model_selection import RandomizedSearchCV

def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

# %%
#mounting Google Drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# ----------------------------------------------------------------------
# ModuleNotFoundError                  Traceback (most recent call last)
# <ipython-input-2-5472941350f4> in <module>
#       1 #mounting Google Drive
# ----> 2 from google.colab import drive
#       3 drive.mount('/content/drive/')
#
# ModuleNotFoundError: No module named 'google'

# %%
cenarios = pd.read_csv('/content/drive/My Drive/HACKATHON_BIG_DATA/cenarios_expansao.csv')

faturamento = pd.read_csv('/content/drive/My Drive/HACKATHON_BIG_DATA/faturamento_lojas_atuais.csv')

lojas = pd.read_csv('/content/drive/My Drive/HACKATHON_BIG_DATA/lojas_atuais.csv')

# %%
faturamento
# Out:
#          cod_loja   ano  mes categoria   qtde   receita
# 0               1  2016    1  CATEG_01  301.0   9164.86
# 1               1  2016    2  CATEG_01  187.0   8175.55
# 2               1  2016    3  CATEG_01  242.0  10521.67
# 3               1  2016    4  CATEG_01  104.0   4560.91
# 4               1  2016    5  CATEG_01  100.0   4263.30
# ...           ...   ...  ...       ...    ...       ...
# 1003089      3687  2017    8  CATEG_14  334.0    634.60
# 1003090      3687  2017    9  CATEG_14   33.0     62.70
# 1003091      3687  2017   10  CATEG_14  184.0    349.60
# 1003092      3687  2017   11  CATEG_14   28.0     61.30
# 1003093      3687  2017   12  CATEG_14  160.0   1527.90
#
# [1003094 rows x 6 columns]

# %%
print(len(faturamento[(faturamento["categoria"] == "CATEG_01")]["cod_loja"].unique()))
print(len(faturamento[(faturamento["categoria"] == "CATEG_02")]["cod_loja"].unique()))
print(len(faturamento[(faturamento["categoria"] == "CATEG_03")]["cod_loja"].unique()))
print(len(faturamento[(faturamento["categoria"] == "CATEG_04")]["cod_loja"].unique()))
print(len(faturamento[(faturamento["categoria"] == "CATEG_05")]["cod_loja"].unique()))
print(len(faturamento[(faturamento["categoria"] == "CATEG_06")]["cod_loja"].unique()))
print(len(faturamento[(faturamento["categoria"] == "CATEG_07")]["cod_loja"].unique()))
print(len(faturamento[(faturamento["categoria"] == "CATEG_08")]["cod_loja"].unique()))
print(len(faturamento[(faturamento["categoria"] == "CATEG_09")]["cod_loja"].unique()))
print(len(faturamento[(faturamento["categoria"] == "CATEG_10")]["cod_loja"].unique()))
print(len(faturamento[(faturamento["categoria"] == "CATEG_11")]["cod_loja"].unique()))
print(len(faturamento[(faturamento["categoria"] == "CATEG_12")]["cod_loja"].unique()))
print(len(faturamento[(faturamento["categoria"] == "CATEG_13")]["cod_loja"].unique()))
print(len(faturamento[(faturamento["categoria"] == "CATEG_14")]["cod_loja"].unique()))
print(len(faturamento[(faturamento["categoria"] == "CATEG_15")]["cod_loja"].unique()))
print(len(faturamento[(faturamento["categoria"] == "CATEG_16")]["cod_loja"].unique()))
print(len(faturamento[(faturamento["categoria"] == "CATEG_17")]["cod_loja"].unique()))
# AS CATEGORIAS SÃO EM COMUM PELAS LOJAs.
# Out:
# 3129
# 3086
# 3129
# 3129
# 3130
# 3128
# 3130
# 3130
# 3130
# 3130
# 3130
# 3130
# 3127
# 3126
# 607
# 1
# 0

# %%
grouped_category = faturamento.groupby("categoria").sum().reset_index()
print(grouped_category)
a4_dims = (17.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.barplot(x="categoria", y="qtde",data=grouped_category, ax=ax)
# Categoria que mais vende é a 11
# Out:
#    categoria   cod_loja        ano     mes        qtde       receita
# 0   CATEG_01  132476201  147870243  477911   2439756.0  6.945954e+07
# 1   CATEG_02   89493739  106336619  333097    266736.0  7.507083e+06
# 2   CATEG_03  133218352  148489301  479647  11254645.0  3.358541e+08
# 3   CATEG_04  132533361  147898445  477789   3087623.0  1.166370e+08
# 4   CATEG_05  133219479  148491319  479659  29984423.0  1.189124e+09
# 5   CATEG_06  131579847  147158329  475403   2054050.0  1.041999e+08
# 6   CATEG_07  133229665  148497369  479681  25616146.0  5.696696e+08
# 7   CATEG_08  132767780  148114232  478566   6360055.0  7.221604e+08
# 8   CATEG_09  133221934  148493336  479661  25982208.0  9.411378e+08
# 9   CATEG_10  133091745  148396539  479350   3746801.0  1.786550e+08
# 10  CATEG_11  133222579  148493334  479669  50952231.0  4.610573e+09
# 11  CATEG_12  133216003  148489303  479643  26080116.0  4.457134e+08
# 12  CATEG_13  127333545  143105134  463776    901184.0  3.581103e+07
# 13  CATEG_14  126642788  141016197  462097  16295325.0  3.680406e+07
# 14  CATEG_15    1426204    1887389    6157      1023.0  3.087954e+04
# 15  CATEG_16        650       4032      14        10.0  2.999000e+02

# %%
grouped_category = faturamento.groupby("categoria").sum().reset_index()
print(grouped_category)
a4_dims = (17.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.barplot(x="categoria", y="receita",data=grouped_category, ax=ax)
# Categoria com maior receita é a 11
# Out:
#    categoria   cod_loja        ano     mes        qtde       receita
# 0   CATEG_01  132476201  147870243  477911   2439756.0  6.945954e+07
# 1   CATEG_02   89493739  106336619  333097    266736.0  7.507083e+06
# 2   CATEG_03  133218352  148489301  479647  11254645.0  3.358541e+08
# 3   CATEG_04  132533361  147898445  477789   3087623.0  1.166370e+08
# 4   CATEG_05  133219479  148491319  479659  29984423.0  1.189124e+09
# 5   CATEG_06  131579847  147158329  475403   2054050.0  1.041999e+08
# 6   CATEG_07  133229665  148497369  479681  25616146.0  5.696696e+08
# 7   CATEG_08  132767780  148114232  478566   6360055.0  7.221604e+08
# 8   CATEG_09  133221934  148493336  479661  25982208.0  9.411378e+08
# 9   CATEG_10  133091745  148396539  479350   3746801.0  1.786550e+08
# 10  CATEG_11  133222579  148493334  479669  50952231.0  4.610573e+09
# 11  CATEG_12  133216003  148489303  479643  26080116.0  4.457134e+08
# 12  CATEG_13  127333545  143105134  463776    901184.0  3.581103e+07
# 13  CATEG_14  126642788  141016197  462097  16295325.0  3.680406e+07
# 14  CATEG_15    1426204    1887389    6157      1023.0  3.087954e+04
# 15  CATEG_16        650       4032      14        10.0  2.999000e+02

# %%
faturamento[(faturamento["cod_loja"] == 1) & (faturamento["categoria"] == "CATEG_01")]
# Fit do preço da categoria?
# Out:
#     cod_loja   ano  mes categoria   qtde   receita
# 0          1  2016    1  CATEG_01  301.0   9164.86
# 1          1  2016    2  CATEG_01  187.0   8175.55
# 2          1  2016    3  CATEG_01  242.0  10521.67
# 3          1  2016    4  CATEG_01  104.0   4560.91
# 4          1  2016    5  CATEG_01  100.0   4263.30
# 5          1  2016    6  CATEG_01  108.0   4741.36
# 6          1  2016    7  CATEG_01  111.0   5604.77
# 7          1  2016    8  CATEG_01   86.0   3987.35
# 8          1  2016    9  CATEG_01  148.0   5543.12
# 9          1  2016   10  CATEG_01  147.0   4996.06
# 10         1  2016   11  CATEG_01  102.0   3090.26
# 11         1  2016   12  CATEG_01  110.0   3650.70
# 12         1  2017    1  CATEG_01  114.0   3584.10
# 13         1  2017    2  CATEG_01   74.0   2261.09
# 14         1  2017    3  CATEG_01  125.0   3461.04
# 15         1  2017    4  CATEG_01  127.0   3832.69
# 16         1  2017    5  CATEG_01  117.0   3705.94
# 17         1  2017    6  CATEG_01  139.0   3570.81
# 18         1  2017    7  CATEG_01  601.0  11081.88
# 19         1  2017    8  CATEG_01  327.0   8460.74
# 20         1  2017    9  CATEG_01  199.0   5579.00
# 21         1  2017   10  CATEG_01  251.0   7546.82
# 22         1  2017   11  CATEG_01  317.0   6837.83
# 23         1  2017   12  CATEG_01  311.0   7606.80

# %%
grouped_category = faturamento.groupby("categoria").sum().reset_index()
grouped_category["mean"] = grouped_category["receita"] / grouped_category["qtde"]
a4_dims = (17.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.barplot(x="categoria", y="mean",data=grouped_category, ax=ax)
# Média de valor da categoria 8 é maior

# %%
grouped_month_year = faturamento.groupby(["ano","mes"]).sum().reset_index()
grouped_month_year['mes_ano'] = grouped_month_year[['ano', 'mes']].astype(str).apply(lambda x: '_'.join(x), axis=1)
a4_dims = (25.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.lineplot(x="mes_ano",y="qtde",data=grouped_month_year,ax=ax)
# Maiores vendas em dezembro provavelemnte por causa do natal

# %%
grouped_month_year = faturamento.groupby(["ano","mes"]).sum().reset_index()
grouped_month_year['mes_ano'] = grouped_month_year[['ano', 'mes']].astype(str).apply(lambda x: '_'.join(x), axis=1)
a4_dims = (25.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.lineplot(x="mes_ano",y="receita",data=grouped_month_year,ax=ax)
# Era de se esperar que a receita seguisse o mesmo padrão

# %%
categoria_summed = faturamento.pivot_table("qtde",["cod_loja",],["categoria"],aggfunc=np.sum, fill_value=0)
categoria_summed
# Out:
# categoria  CATEG_01  CATEG_02  CATEG_03  ...  CATEG_14  CATEG_15  CATEG_16
# cod_loja                                 ...
# 1              4448      2110     46464  ...      3705         0         0
# 2              1875        48      1623  ...      3336         0         0
# 3              1211       167      5163  ...      8118         0         0
# 4               519        61      3211  ...      2195         0         0
# 5              1326       125      5443  ...     12939         0         0
# ...             ...       ...       ...  ...       ...       ...       ...
# 3682           1217       191      4790  ...      2284         0         0
# 3683            369        16      2380  ...      9960         0         0
# 3685           1825       399      8661  ...      3336         2         0
# 3686            522        44      3912  ...      4923         0         0
# 3687            560        73      2768  ...      1727         0         0
#
# [3130 rows x 16 columns]

# %%
df = categoria_summed
f = plt.figure(figsize=(19, 15))
corr = df.corr()
plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=45)
plt.yticks(range(df.shape[1]), df.columns, fontsize=14)
plt.title('Correlation Matrix', fontsize=16);
sns.heatmap(corr, annot=True)
plt.show()

# %%
categoria_summed = faturamento.pivot_table("receita",["cod_loja",],["categoria"],aggfunc=np.sum, fill_value=0)
df = categoria_summed
f = plt.figure(figsize=(19, 15))
corr = df.corr()
plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=45)
plt.yticks(range(df.shape[1]), df.columns, fontsize=14)
plt.title('Correlation Matrix', fontsize=16);
sns.heatmap(corr, annot=True)
plt.show()

# %%
cenarios
# Out:
#      cod_loja         cod_ap  cod_municipio  ... feature_16 feature_17  feature_18
# 0          10  2933307005008        2933307  ...      100.0       71.7        88.8
# 1          13  2916401003002        2916401  ...      100.0       63.5        78.8
# 2          16  2928703003003        2928703  ...        NaN        NaN         NaN
# 3          21  2906006003001        2906006  ...      100.0      100.0        92.9
# 4          28  3550308005058        3550308  ...        NaN        NaN         NaN
# ..        ...            ...            ...  ...        ...        ...         ...
# 548      3667  2927408005009        2927408  ...        NaN        NaN         NaN
# 549      3672             -1             -1  ...        NaN        NaN         NaN
# 550      3674  5208707005001        5208707  ...      100.0       60.6        81.1
# 551      3675  4218202003002        4218202  ...      100.0       94.2        96.6
# 552      3684  2917607003002        2917607  ...       50.0       99.7        85.6
#
# [553 rows x 21 columns]

# %%
lojas
# Out:
#       cod_loja         cod_ap  ...  feature_17 feature_18
# 0            1  4125506005002  ...         NaN        NaN
# 1            2  5300108005004  ...         NaN        NaN
# 2            3  3550308005052  ...         NaN        NaN
# 3            4  3145604003002  ...         NaN        NaN
# 4            5  1600303005010  ...        88.5       93.8
# ...        ...            ...  ...         ...        ...
# 3125      3682  5105259003002  ...        97.1       97.6
# 3126      3683  2604106003003  ...        50.7       72.5
# 3127      3685  4115804003002  ...        99.0       95.2
# 3128      3686  3509700003001  ...         NaN        NaN
# 3129      3687  4211702001001  ...         NaN        NaN
#
# [3130 rows x 21 columns]

# %%
id_lojas_expansao = list(cenarios["cod_loja"].values)
id_lojas = list(lojas["cod_loja"].values)
id_faturamento = list(set(faturamento["cod_loja"].values))

# %%
def intersection(lst1, lst2): 
    lst3 = [value for value in lst1 if value in lst2] 
    return lst3 

print(intersection(id_lojas_expansao, id_lojas))
print(intersection(id_lojas_expansao, id_faturamento))
# Out:
# []
# []

# %%
grouped_month_year = faturamento.groupby(["ano","mes"]).sum().reset_index()
#grouped_month_year['mes_ano'] = grouped_month_year[['ano', 'mes']].astype(str).apply(lambda x: '_'.join(x), axis=1)
a4_dims = (25.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
plt.xticks(range(1,13), range(1,13), fontsize=14, rotation=45)
sns.lineplot(x="mes",y="qtde",hue="ano",data=grouped_month_year,ax=ax,palette="tab10")

# %%
grouped_month_year = faturamento.groupby(["ano","mes"]).sum().reset_index()
#grouped_month_year['mes_ano'] = grouped_month_year[['ano', 'mes']].astype(str).apply(lambda x: '_'.join(x), axis=1)
a4_dims = (25.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
plt.xticks(range(1,13), range(1,13), fontsize=14, rotation=45)
sns.lineplot(x="mes",y="receita",hue="ano",data=grouped_month_year,ax=ax,palette="tab10")

# %%
grouped_month_year = faturamento.groupby(["ano","mes"]).sum().reset_index()
print(grouped_month_year)
print(grouped_month_year.iloc[0:3, 4].mean())
print(grouped_month_year.iloc[12:15, 4].mean())
# Out:
#      ano  mes  cod_loja        qtde       receita
# 0   2016    1  74720437   9698606.0  3.647849e+08
# 1   2016    2  74987316   6662430.0  2.588566e+08
# 2   2016    3  73874325   6995814.0  3.081491e+08
# 3   2016    4  73828477   6877068.0  3.165124e+08
# 4   2016    5  74091920   9488125.0  4.551395e+08
# 5   2016    6  74494399   9323234.0  3.817513e+08
# 6   2016    7  74195003   6813839.0  3.164418e+08
# 7   2016    8  74405668   7606399.0  3.799631e+08
# 8   2016    9  74130226   6525752.0  3.143483e+08
# 9   2016   10  74224566   7918774.0  3.424379e+08
# 10  2016   11  74849797   8318838.0  3.980086e+08
# 11  2016   12  76502826  16269580.0  7.985149e+08
# 12  2017    1  74355603   6859028.0  3.202394e+08
# 13  2017    2  75556772   6134230.0  2.711384e+08
# 14  2017    3  75768378   8132403.0  3.297410e+08
# 15  2017    4  75446450   6798805.0  3.174659e+08
# 16  2017    5  75713424   9281869.0  4.845270e+08
# 17  2017    6  76402024   8183317.0  4.076820e+08
# 18  2017    7  76254452   6696136.0  3.127994e+08
# 19  2017    8  75917521   9505699.0  4.025505e+08
# 20  2017    9  76181134   7694658.0  3.334951e+08
# 21  2017   10  76058203   7987736.0  3.272693e+08
# 22  2017   11  77176993   9564936.0  4.362719e+08
# 23  2017   12  77537958  15685056.0  7.852493e+08
# 310596831.1133331
# 307039602.7766648

# %%
print(lojas.columns)
# Out:
# Index(['cod_loja', 'cod_ap', 'cod_municipio', 'feature_01', 'feature_02',
#        'feature_03', 'feature_04', 'feature_05', 'feature_06', 'feature_07',
#        'feature_08', 'feature_09', 'feature_10', 'feature_11', 'feature_12',
#        'feature_13', 'feature_14', 'feature_15', 'feature_16', 'feature_17',
#        'feature_18'],
#       dtype='object')

# %%
id_lojas_expansao = list(cenarios["cod_municipio"].values)
id_lojas = list(lojas["cod_municipio"].values)
def intersection(lst1, lst2): 
    lst3 = [value for value in lst1 if value in lst2] 
    return lst3 

print(intersection(id_lojas_expansao, id_lojas))
inter_list = intersection(id_lojas_expansao, id_lojas)
print(len(inter_list)/len(id_lojas_expansao))
print(len(inter_list))
print(len(id_lojas_expansao))
# Out:
# [2933307, 2928703, 3550308, 3523404, 3516200, 3170206, 3132404, 4203808, 4122305, 4122404, 4104303, 3118601, 3205309, 3169901, 3543402, 3170206, 3511102, 3535507, 4314902, 2402006, 3303906, 4314902, 3501608, 3543402, 3550308, 3550308, 3543402, 3550308, 3516200, 3300100, 3104007, 3201209, 3525904, 5208707, 3171303, 3205200, 4125605, 3205002, 3302502, 3552205, 3169307, 3106200, 2924009, 3136702, 4314902, 4108304, 3134202, -1, 4302105, 2930501, 5103403, 3550308, -1, 3548500, 3550308, 2408102, 2414407, 4323002, 3170206, 3170206, 3530607, 3304557, 3550308, -1, 3515707, 3303302, 4208203, 4216602, 3303906, 3154606, 3552205, -1, 3507605, 3205002, 5101803, 4309209, 3550308, 2606408, 3552205, 3543402, 3550308, -1, 4115200, 3304557, 2604106, 3550308, 3148103, 3550308, 3147907, 3106200, 2910800, 2101400, 3550308, 3538709, 5002704, 2910800, 3118601, 3550308, 2927408, -1, 3550308, 3548807, 3550308, 3550308, 3556206, 3543402, 3550308, 4115200, 3525904, 1504208, 5211909, -1, -1, -1, 3501608, 3554102, 5201108, 3538709, 3513801, 1302603, 4314902, 3550308, 4309209, 4318705, 3550308, 3550308, 3170206, 3205002, 3550308, 2501807, 3205002, 3530706, -1, 5008305, 3120904, 1721000, 2802908, 2111300, 5102504, 2408102, 2704302, -1, 4204202, 3127701, 3515004, 3550308, 3548708, 3509502, 2403251, 3550308, 3541406, 3106200, 3549904, 4106902, 5300108, 3509502, 4128104, 4209300, 3541406, 2704302, 5300108, 3170404, 3516200, 3550308, 3502507, 3304557, 5208707, 3303500, 4202404, 3550308, 3154606, 2602902, 5208707, 4202404, -1, 4113700, 5300108, 3106200, 4209102, 3106200, 3106200, 3106200, 2800308, 2800308, 2800308, 3518800, 4106902, 4106902, 4106902, 4106902, 3550308, 4106902, 1600600, 3550308, 4215802, 2602902, 3550308, 3550605, 3550308, 3106200, 4104808, 3523107, -1, 3170206, 2610707, 4118204, 5212501, -1, 3303302, 3106200, 3543402, 3305802, 2905701, -1, 2918001, -1, 4314902, 4314902, 4216602, 3543402, 2408102, 3304557, 4113700, 4108304, -1, 3550308, 3554102, 2304400, -1, -1, 4119152, -1, 3529401, 3550308, 4106902, 2304400, 3550308, 3534401, 2305506, 4310207, 5105259, 3550308, 1100205, 3304557, 4106902, 3304557, 3300704, -1, 3127701, 3137205, 3518800, 3530706, 3513108, 2111300, 3304557, 3304557, 2611101, 3522307, 3549904, 3201308, 3508504, 3143906, 2305506, 4209102, 3304557, 4202909, 3519071, 3550308, 3541406, 2304400, 3154606, 3550308, 1200401, 4119905, -1, 4314902, 3303500, 3303500, 4118204, 3304557, 3304557, 4115200, 5103403, 3509205, 2211001, 5204508, -1, 3302700, -1, 3527207, 3555406, 4105805, 3501608, 1100304, 3547809, 3550308, 2933307, 3506102, 3170701, 3547809, 3548708, 3518404, 3550308, 3552205, -1, 3519600, 2613909, 4202008, 3550308, 1502400, -1, 3550308, 2927408, 2927408, 2927408, 2927408, 3530607, 2927408, 2927408, 2927408, 2927408, -1, 2507507, 3118601, 1505536, 3550308, 4106902, 2507507, -1, 3205002, 2611606, 2607901, 2611606, 3523909, 4301602, 2611606, 2611606, 2611606, 1501402, 1501402, 1501402, 1500800, 1501402, 1501402, 3550308, 4305108, -1, 2611606, 5300108, 3205002, 3304557, 2927408, -1, 5208707]
# 0.6401446654611211
# 354
# 553

# %%
# Verificar a correlação entre média de de 2016 e 2017 
grouped_loja_ano_mes = faturamento.groupby(["cod_loja","ano","mes"]).sum().reset_index()
grouped_loja_ano_mes
# Out:
#        cod_loja   ano  mes     qtde    receita
# 0             1  2016    1  13034.0  441833.37
# 1             1  2016    2  11411.0  395340.22
# 2             1  2016    3  15030.0  587810.18
# 3             1  2016    4  12726.0  534618.84
# 4             1  2016    5  13978.0  595477.92
# ...         ...   ...  ...      ...        ...
# 73639      3687  2017    8   1864.0   71171.48
# 73640      3687  2017    9   1257.0   48284.66
# 73641      3687  2017   10   1709.0   61198.10
# 73642      3687  2017   11   2039.0   73877.02
# 73643      3687  2017   12   4398.0  186545.24
#
# [73644 rows x 5 columns]

# %%
filtered_month = grouped_loja_ano_mes[(grouped_loja_ano_mes["mes"] == 1) | (grouped_loja_ano_mes["mes"] == 2)  | (grouped_loja_ano_mes["mes"] == 3)]
filtered_month
# Out:
#        cod_loja   ano  mes     qtde    receita
# 0             1  2016    1  13034.0  441833.37
# 1             1  2016    2  11411.0  395340.22
# 2             1  2016    3  15030.0  587810.18
# 12            1  2017    1  10065.0  404108.77
# 13            1  2017    2  11107.0  483610.18
# ...         ...   ...  ...      ...        ...
# 73621      3687  2016    2   1269.0   40147.63
# 73622      3687  2016    3   1597.0   56621.60
# 73632      3687  2017    1   1317.0   49269.30
# 73633      3687  2017    2   1153.0   39229.17
# 73634      3687  2017    3   1789.0   63369.27
#
# [18338 rows x 5 columns]

# %%
filtered_month['mes_ano'] = filtered_month[['ano', 'mes']].astype(str).apply(lambda x: '_'.join(x), axis=1)
filtered_month
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        cod_loja   ano  mes     qtde    receita mes_ano
# 0             1  2016    1  13034.0  441833.37  2016_1
# 1             1  2016    2  11411.0  395340.22  2016_2
# 2             1  2016    3  15030.0  587810.18  2016_3
# 12            1  2017    1  10065.0  404108.77  2017_1
# 13            1  2017    2  11107.0  483610.18  2017_2
# ...         ...   ...  ...      ...        ...     ...
# 73621      3687  2016    2   1269.0   40147.63  2016_2
# 73622      3687  2016    3   1597.0   56621.60  2016_3
# 73632      3687  2017    1   1317.0   49269.30  2017_1
# 73633      3687  2017    2   1153.0   39229.17  2017_2
# 73634      3687  2017    3   1789.0   63369.27  2017_3
#
# [18338 rows x 6 columns]

# %%
filtered_month_pivoted = filtered_month.pivot_table("receita",["cod_loja"],["mes_ano"])
filtered_month_pivoted
# Out:
# mes_ano      2016_1     2016_2     2016_3     2017_1     2017_2     2017_3
# cod_loja
# 1         441833.37  395340.22  587810.18  404108.77  483610.18  626291.59
# 2          54660.39   49120.72   53421.91   55235.99   39019.13   62446.56
# 3         161428.96  132417.93  139495.61  131512.12  130868.47  141768.81
# 4          54363.21   38433.23   43751.17   48694.93   42445.06   51014.55
# 5         248834.01  182297.02  210579.83  192211.08  151167.08  177428.43
# ...             ...        ...        ...        ...        ...        ...
# 3682      121727.10   96526.36  150817.29  106572.49  105736.48  132543.17
# 3683      190014.89  107871.65  125584.12  167519.47  129491.36  130658.08
# 3685      187775.61  145430.99  184151.12  182564.30  125240.48  192202.86
# 3686       85259.81   53781.67   49293.02   78711.76   63761.34   62940.56
# 3687       48988.51   40147.63   56621.60   49269.30   39229.17   63369.27
#
# [3090 rows x 6 columns]

# %%
df = filtered_month_pivoted
f = plt.figure(figsize=(19, 15))
corr = df.corr()
plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=45)
plt.yticks(range(df.shape[1]), df.columns, fontsize=14)
plt.title('Correlation Matrix', fontsize=16);
sns.heatmap(corr, annot=True)
plt.show()

# %%
grouped_loja_ano_mes['mes_ano'] = grouped_loja_ano_mes[['ano', 'mes']].astype(str).apply(lambda x: '_'.join(x), axis=1)
grouped_loja_ano_mes = grouped_loja_ano_mes.pivot_table("receita",["cod_loja"],["mes_ano"])
print(grouped_loja_ano_mes.columns)
grouped_loja_ano_mes
# Out:
# Index(['2016_1', '2016_10', '2016_11', '2016_12', '2016_2', '2016_3', '2016_4',
#        '2016_5', '2016_6', '2016_7', '2016_8', '2016_9', '2017_1', '2017_10',
#        '2017_11', '2017_12', '2017_2', '2017_3', '2017_4', '2017_5', '2017_6',
#        '2017_7', '2017_8', '2017_9'],
#       dtype='object', name='mes_ano')
# mes_ano      2016_1    2016_10    2016_11  ...     2017_7     2017_8     2017_9
# cod_loja                                   ...
# 1         441833.37  611797.30  876921.63  ...  646369.23  757850.68  602313.53
# 2          54660.39   53209.15   53830.14  ...   60697.95   72463.56   64936.11
# 3         161428.96  198425.47  199192.78  ...  132580.46  173861.61  142303.83
# 4          54363.21   41540.57   57029.49  ...   42618.25   58756.90   50140.08
# 5         248834.01  219199.82  250667.71  ...  177883.45  220496.40  179435.96
# ...             ...        ...        ...  ...        ...        ...        ...
# 3682      121727.10  135680.82  165448.69  ...  129052.07  164097.51  135871.52
# 3683      190014.89  146891.10  198892.84  ...  117836.80  181790.37  146123.72
# 3685      187775.61  168270.33  203865.09  ...  169798.69  231486.83  152709.19
# 3686       85259.81   65652.53   89173.66  ...   91052.07  116510.26   92081.35
# 3687       48988.51   48056.18   63038.21  ...   47865.16   71171.48   48284.66
#
# [3130 rows x 24 columns]

# %%
df = grouped_loja_ano_mes
f = plt.figure(figsize=(19, 15))
corr = df.corr()
plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=45)
plt.yticks(range(df.shape[1]), df.columns, fontsize=14)
plt.title('Correlation Matrix', fontsize=16);
sns.heatmap(corr, annot=True)
plt.show()

# %%
grouped_loja_ano_mes
# Out:
# mes_ano      2016_1    2016_10    2016_11  ...     2017_7     2017_8     2017_9
# cod_loja                                   ...
# 1         441833.37  611797.30  876921.63  ...  646369.23  757850.68  602313.53
# 2          54660.39   53209.15   53830.14  ...   60697.95   72463.56   64936.11
# 3         161428.96  198425.47  199192.78  ...  132580.46  173861.61  142303.83
# 4          54363.21   41540.57   57029.49  ...   42618.25   58756.90   50140.08
# 5         248834.01  219199.82  250667.71  ...  177883.45  220496.40  179435.96
# ...             ...        ...        ...  ...        ...        ...        ...
# 3682      121727.10  135680.82  165448.69  ...  129052.07  164097.51  135871.52
# 3683      190014.89  146891.10  198892.84  ...  117836.80  181790.37  146123.72
# 3685      187775.61  168270.33  203865.09  ...  169798.69  231486.83  152709.19
# 3686       85259.81   65652.53   89173.66  ...   91052.07  116510.26   92081.35
# 3687       48988.51   48056.18   63038.21  ...   47865.16   71171.48   48284.66
#
# [3130 rows x 24 columns]

# %%
removed_nan = grouped_loja_ano_mes.dropna(0,subset=["2017_1"])

# %%
features = ['2016_1', '2016_10', '2016_11', '2016_12', '2016_2', '2016_3', '2016_4',
       '2016_5', '2016_6', '2016_7', '2016_8', '2016_9']
X = removed_nan[features].fillna(0)
target = ['2017_1']
Y = removed_nan[target]

# %%
print(X)
# Out:
# mes_ano      2016_1    2016_10    2016_11  ...     2016_7     2016_8     2016_9
# cod_loja                                   ...
# 1         441833.37  611797.30  876921.63  ...  563814.03  625181.36  583509.12
# 2          54660.39   53209.15   53830.14  ...   69741.67   65833.00   56715.82
# 3         161428.96  198425.47  199192.78  ...  137311.66  189264.08  176922.79
# 4          54363.21   41540.57   57029.49  ...   45347.35   58360.33   40406.35
# 5         248834.01  219199.82  250667.71  ...  223261.58  255071.70  198355.78
# ...             ...        ...        ...  ...        ...        ...        ...
# 3682      121727.10  135680.82  165448.69  ...  137734.89  162033.94  119345.27
# 3683      190014.89  146891.10  198892.84  ...  128065.87  171816.95  124519.02
# 3685      187775.61  168270.33  203865.09  ...  155068.66  222887.62  174555.50
# 3686       85259.81   65652.53   89173.66  ...   68652.67   84115.04   71382.88
# 3687       48988.51   48056.18   63038.21  ...   47546.03   60410.09   47724.22
#
# [3087 rows x 12 columns]

# %%
seed = 7
test_size = 0.33
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
model = xgboost.XGBRegressor(objective="reg:squarederror", random_state=42)

# %%
score = cross_val_score(model, X_train, y_train, scoring="neg_root_mean_squared_error", cv=5)
display_scores(np.sqrt(-score))
# Out:
# Scores: [120.58362847 125.6036924  148.9295192  128.22537903 125.09534788]
# Mean: 129.68751339652724
# Standard deviation: 9.93014524587887

# %%
model = model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mean_squared_error(y_test,y_pred)
# Out:
# 276065592.6592041

# %%
# plot feature importance
fig, ax = plt.subplots(1,1,figsize=(15,15))
plot_importance(model, ax=ax)
plt.show()

# %%
lasso_model = linear_model.Lasso(max_iter=5000)

# %%
#score = model.cross_valscore(X_train,y_train)

score = cross_val_score(lasso_model, X_train, y_train, scoring="neg_root_mean_squared_error", cv=5)
display_scores(np.sqrt(-score))
# Out:
# Scores: [121.11011386 125.19470001 153.93605285 124.70221207 117.92835253]
# Mean: 128.5742862642023
# Standard deviation: 12.951320709656338

# %%
lasso_model_lars = linear_model.LassoLars(max_iter=5000)

# %%
#score = model.cross_valscore(X_train,y_train)

score = cross_val_score(lasso_model_lars, X_train, y_train, scoring="neg_root_mean_squared_error", cv=5)
display_scores(np.sqrt(-score))
# Out:
# Scores: [121.32088732 124.6707617  154.28508567 124.57468381 117.71600708]
# Mean: 128.51348511660353
# Standard deviation: 13.136019711805302

# %%
regression = linear_model.LinearRegression()

# %%
#score = model.cross_valscore(X_train,y_train)

score = cross_val_score(regression, X_train, y_train, scoring="neg_root_mean_squared_error", cv=5)
display_scores(np.sqrt(-score))
# Out:
# Scores: [121.11011388 125.19470017 153.93605276 124.70221213 117.92835262]
# Mean: 128.5742863117255
# Standard deviation: 12.951320646970295

# %%
decision_regression = tree.DecisionTreeRegressor()

# %%
score = cross_val_score(decision_regression, X_train, y_train, scoring="neg_root_mean_squared_error", cv=5)
display_scores(np.sqrt(-score))
# Out:
# Scores: [140.33752331 150.32589177 165.50514952 148.64286269 158.34505155]
# Mean: 152.631295769495
# Standard deviation: 8.610951664869736

# %%
lojas
# Out:
#       cod_loja         cod_ap  ...  new_feature_11 new_feature_12
# 0            1  4125506005002  ...             NaN            NaN
# 1            2  5300108005004  ...             NaN            NaN
# 2            3  3550308005052  ...             NaN            NaN
# 3            4  3145604003002  ...             NaN            NaN
# 4            5  1600303005010  ...             2.0            1.0
# ...        ...            ...  ...             ...            ...
# 3125      3682  5105259003002  ...             NaN            NaN
# 3126      3683  2604106003003  ...             NaN            NaN
# 3127      3685  4115804003002  ...             NaN            NaN
# 3128      3686  3509700003001  ...             NaN            NaN
# 3129      3687  4211702001001  ...             NaN            NaN
#
# [3130 rows x 27 columns]

# %%
print(lojas["feature_01"].unique())
map_features_01 = {'FEATURE_01_VALUE_10':4, 'FEATURE_01_VALUE_08':3, 'FEATURE_01_VALUE_03':1,
 'FEATURE_01_VALUE_06':2}
# Out:
# [nan 'FEATURE_01_VALUE_10' 'FEATURE_01_VALUE_08' 'FEATURE_01_VALUE_03'
#  'FEATURE_01_VALUE_06']

# %%
lojas["new_feature_01"] = lojas["feature_01"].map(map_features_01)

# %%
print(lojas["feature_02"].unique())
map_features_02 = {'FEATURE_02_VALUE_04':3, 'FEATURE_02_VALUE_03':2, 'FEATURE_02_VALUE_02':1,
 'FEATURE_02_VALUE_06':4}
# Out:
# ['FEATURE_02_VALUE_04' 'FEATURE_02_VALUE_03' 'FEATURE_02_VALUE_02'
#  'FEATURE_02_VALUE_06']

# %%
lojas["new_feature_02"] = lojas["feature_02"].map(map_features_02)

# %%
print(lojas["feature_03"].unique())
map_features_03 = {True:1, False:0}
# Out:
# [ True False]

# %%
lojas["new_feature_03"] = lojas["feature_03"].map(map_features_03)

# %%
print(lojas["feature_05"].unique())
map_features_05 = {'FEATURE_05_VALUE_04':4, 'FEATURE_05_VALUE_03':3, 'FEATURE_05_VALUE_06':6,
 'FEATURE_05_VALUE_07':7, 'FEATURE_05_VALUE_02':2, 'FEATURE_05_VALUE_05':5,
 'FEATURE_05_VALUE_01':1, 'FEATURE_05_VALUE_08':8}
# Out:
# ['FEATURE_05_VALUE_04' 'FEATURE_05_VALUE_03' 'FEATURE_05_VALUE_06'
#  'FEATURE_05_VALUE_07' 'FEATURE_05_VALUE_02' 'FEATURE_05_VALUE_05'
#  'FEATURE_05_VALUE_01' 'FEATURE_05_VALUE_08']

# %%
lojas["new_feature_05"] = lojas["feature_05"].map(map_features_05)

# %%
print(lojas["feature_11"].unique())
map_features_11= {'FEATURE_11_VALUE_02':2, 'FEATURE_11_VALUE_06':6, 'FEATURE_11_VALUE_07':7,
 'FEATURE_11_VALUE_01':1, 'FEATURE_11_VALUE_04':4, 'FEATURE_11_VALUE_03':3,
 'FEATURE_11_VALUE_05':5}
# Out:
# [nan 'FEATURE_11_VALUE_02' 'FEATURE_11_VALUE_06' 'FEATURE_11_VALUE_07'
#  'FEATURE_11_VALUE_01' 'FEATURE_11_VALUE_04' 'FEATURE_11_VALUE_03'
#  'FEATURE_11_VALUE_05']

# %%
lojas["new_feature_11"] = lojas["feature_11"].map(map_features_11)

# %%
print(lojas["feature_12"].unique())
map_features_12= {'FEATURE_12_VALUE_01':1, 'FEATURE_12_VALUE_02':2}
# Out:
# [nan 'FEATURE_12_VALUE_01' 'FEATURE_12_VALUE_02']

# %%
lojas["new_feature_12"] = lojas["feature_12"].map(map_features_12)

# %%
lojas
# Out:
#       cod_loja         cod_ap  ...  new_feature_11 new_feature_12
# 0            1  4125506005002  ...             NaN            NaN
# 1            2  5300108005004  ...             NaN            NaN
# 2            3  3550308005052  ...             NaN            NaN
# 3            4  3145604003002  ...             NaN            NaN
# 4            5  1600303005010  ...             2.0            1.0
# ...        ...            ...  ...             ...            ...
# 3125      3682  5105259003002  ...             NaN            NaN
# 3126      3683  2604106003003  ...             NaN            NaN
# 3127      3685  4115804003002  ...             NaN            NaN
# 3128      3686  3509700003001  ...             NaN            NaN
# 3129      3687  4211702001001  ...             NaN            NaN
#
# [3130 rows x 27 columns]

# %%
lojas_filtered_columns = lojas[["cod_loja","cod_ap","cod_municipio","new_feature_01","new_feature_02","new_feature_03","feature_04","new_feature_05","feature_06","feature_07","feature_08",
                                "feature_09","feature_10","new_feature_11","new_feature_12","feature_13","feature_14","feature_15","feature_16","feature_17","feature_18"]]

# %%
lojas_filtered_columns
# Out:
#       cod_loja         cod_ap  ...  feature_17  feature_18
# 0            1  4125506005002  ...         NaN         NaN
# 1            2  5300108005004  ...         NaN         NaN
# 2            3  3550308005052  ...         NaN         NaN
# 3            4  3145604003002  ...         NaN         NaN
# 4            5  1600303005010  ...        88.5        93.8
# ...        ...            ...  ...         ...         ...
# 3125      3682  5105259003002  ...        97.1        97.6
# 3126      3683  2604106003003  ...        50.7        72.5
# 3127      3685  4115804003002  ...        99.0        95.2
# 3128      3686  3509700003001  ...         NaN         NaN
# 3129      3687  4211702001001  ...         NaN         NaN
#
# [3130 rows x 21 columns]

# %%
removed_nan_index_to_column = removed_nan.reset_index(level=0, inplace=False)
print(removed_nan_index_to_column)
# Out:
# mes_ano  cod_loja     2016_1    2016_10  ...     2017_7     2017_8     2017_9
# 0               1  441833.37  611797.30  ...  646369.23  757850.68  602313.53
# 1               2   54660.39   53209.15  ...   60697.95   72463.56   64936.11
# 2               3  161428.96  198425.47  ...  132580.46  173861.61  142303.83
# 3               4   54363.21   41540.57  ...   42618.25   58756.90   50140.08
# 4               5  248834.01  219199.82  ...  177883.45  220496.40  179435.96
# ...           ...        ...        ...  ...        ...        ...        ...
# 3082         3682  121727.10  135680.82  ...  129052.07  164097.51  135871.52
# 3083         3683  190014.89  146891.10  ...  117836.80  181790.37  146123.72
# 3084         3685  187775.61  168270.33  ...  169798.69  231486.83  152709.19
# 3085         3686   85259.81   65652.53  ...   91052.07  116510.26   92081.35
# 3086         3687   48988.51   48056.18  ...   47865.16   71171.48   48284.66
#
# [3087 rows x 25 columns]

# %%
estatico_faturamento = removed_nan_index_to_column.merge(lojas_filtered_columns)

# %%
features = ['2016_1', '2016_10', '2016_11', '2016_12', '2016_2', '2016_3', '2016_4',
       '2016_5', '2016_6', '2016_7', '2016_8', '2016_9',"cod_ap","cod_municipio","new_feature_01","new_feature_02","new_feature_03","feature_04","new_feature_05","feature_06","feature_07","feature_08",
                                "feature_09","feature_10","new_feature_11","new_feature_12","feature_13","feature_14","feature_15","feature_16","feature_17","feature_18"]
X = estatico_faturamento[features].fillna(0)
target = ['2017_1']
Y = estatico_faturamento[target]

# %%
print(X)
# Out:
#          2016_1    2016_10    2016_11  ...  feature_16  feature_17  feature_18
# 0     441833.37  611797.30  876921.63  ...         0.0         0.0         0.0
# 1      54660.39   53209.15   53830.14  ...         0.0         0.0         0.0
# 2     161428.96  198425.47  199192.78  ...         0.0         0.0         0.0
# 3      54363.21   41540.57   57029.49  ...         0.0         0.0         0.0
# 4     248834.01  219199.82  250667.71  ...       100.0        88.5        93.8
# ...         ...        ...        ...  ...         ...         ...         ...
# 3082  121727.10  135680.82  165448.69  ...       100.0        97.1        97.6
# 3083  190014.89  146891.10  198892.84  ...       100.0        50.7        72.5
# 3084  187775.61  168270.33  203865.09  ...       100.0        99.0        95.2
# 3085   85259.81   65652.53   89173.66  ...         0.0         0.0         0.0
# 3086   48988.51   48056.18   63038.21  ...         0.0         0.0         0.0
#
# [3087 rows x 32 columns]

# %%
seed = 7
test_size = 0.33
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
model = xgboost.XGBRegressor(objective="reg:squarederror", random_state=42)
score = cross_val_score(model, X_train, y_train, scoring="neg_root_mean_squared_error", cv=5)
display_scores(np.sqrt(-score))
# Out:
# Scores: [120.81711136 124.28200771 148.26684774 127.12233854 127.20877596]
# Mean: 129.53941626119894
# Standard deviation: 9.651008092178198

# %%
model = model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mean_squared_error(y_test,y_pred)
# Out:
# 237067788.23158845

# %%
# plot feature importance
f = plt.figure(figsize=(19, 15))
fig, ax = plt.subplots(1,1,figsize=(19,15))
plot_importance(model, ax=ax)
plt.show()

# %%
lojas = pd.read_csv('/content/drive/My Drive/HACKATHON_BIG_DATA/lojas_atuais.csv')
lojas
# Out:
#       cod_loja         cod_ap  ...  feature_17 feature_18
# 0            1  4125506005002  ...         NaN        NaN
# 1            2  5300108005004  ...         NaN        NaN
# 2            3  3550308005052  ...         NaN        NaN
# 3            4  3145604003002  ...         NaN        NaN
# 4            5  1600303005010  ...        88.5       93.8
# ...        ...            ...  ...         ...        ...
# 3125      3682  5105259003002  ...        97.1       97.6
# 3126      3683  2604106003003  ...        50.7       72.5
# 3127      3685  4115804003002  ...        99.0       95.2
# 3128      3686  3509700003001  ...         NaN        NaN
# 3129      3687  4211702001001  ...         NaN        NaN
#
# [3130 rows x 21 columns]

# %%
feature_01_dummy = pd.get_dummies(lojas.feature_01)
feature_02_dummy = pd.get_dummies(lojas.feature_02)
feature_05_dummy = pd.get_dummies(lojas.feature_05)
feature_11_dummy = pd.get_dummies(lojas.feature_11)
feature_12_dummy = pd.get_dummies(lojas.feature_12)
hot_encoded_lojas = pd.concat([lojas,feature_01_dummy,feature_02_dummy,feature_05_dummy,feature_11_dummy,feature_12_dummy],axis=1)
print(hot_encoded_lojas)
# Out:
#       cod_loja         cod_ap  ...  FEATURE_12_VALUE_01 FEATURE_12_VALUE_02
# 0            1  4125506005002  ...                    0                   0
# 1            2  5300108005004  ...                    0                   0
# 2            3  3550308005052  ...                    0                   0
# 3            4  3145604003002  ...                    0                   0
# 4            5  1600303005010  ...                    1                   0
# ...        ...            ...  ...                  ...                 ...
# 3125      3682  5105259003002  ...                    0                   0
# 3126      3683  2604106003003  ...                    0                   0
# 3127      3685  4115804003002  ...                    0                   0
# 3128      3686  3509700003001  ...                    0                   0
# 3129      3687  4211702001001  ...                    0                   0
#
# [3130 rows x 46 columns]

# %%
hot_encoded_lojas = hot_encoded_lojas.drop(columns=["feature_01","feature_02","feature_05","feature_11","feature_12"])
print(hot_encoded_lojas)
# Out:
#       cod_loja         cod_ap  ...  FEATURE_12_VALUE_01  FEATURE_12_VALUE_02
# 0            1  4125506005002  ...                    0                    0
# 1            2  5300108005004  ...                    0                    0
# 2            3  3550308005052  ...                    0                    0
# 3            4  3145604003002  ...                    0                    0
# 4            5  1600303005010  ...                    1                    0
# ...        ...            ...  ...                  ...                  ...
# 3125      3682  5105259003002  ...                    0                    0
# 3126      3683  2604106003003  ...                    0                    0
# 3127      3685  4115804003002  ...                    0                    0
# 3128      3686  3509700003001  ...                    0                    0
# 3129      3687  4211702001001  ...                    0                    0
#
# [3130 rows x 41 columns]

# %%
estatico_faturamento = removed_nan_index_to_column.merge(hot_encoded_lojas)
print(estatico_faturamento)
print(estatico_faturamento.columns)
# Out:
#       cod_loja     2016_1  ...  FEATURE_12_VALUE_01  FEATURE_12_VALUE_02
# 0            1  441833.37  ...                    0                    0
# 1            2   54660.39  ...                    0                    0
# 2            3  161428.96  ...                    0                    0
# 3            4   54363.21  ...                    0                    0
# 4            5  248834.01  ...                    1                    0
# ...        ...        ...  ...                  ...                  ...
# 3082      3682  121727.10  ...                    0                    0
# 3083      3683  190014.89  ...                    0                    0
# 3084      3685  187775.61  ...                    0                    0
# 3085      3686   85259.81  ...                    0                    0
# 3086      3687   48988.51  ...                    0                    0
#
# [3087 rows x 65 columns]
# Index(['cod_loja', '2016_1', '2016_10', '2016_11', '2016_12', '2016_2',
#        '2016_3', '2016_4', '2016_5', '2016_6', '2016_7', '2016_8', '2016_9',
#        '2017_1', '2017_10', '2017_11', '2017_12', '2017_2', '2017_3', '2017_4',
#        '2017_5', '2017_6', '2017_7', '2017_8', '2017_9', 'cod_ap',
#        'cod_municipio', 'feature_03', 'feature_04', 'feature_06', 'feature_07',
#        'feature_08', 'feature_09', 'feature_10', 'feature_13', 'feature_14',
#        'feature_15', 'feature_16', 'feature_17', 'feature_18',
#        'FEATURE_01_VALUE_03', 'FEATURE_01_VALUE_06', 'FEATURE_01_VALUE_08',
#        'FEATURE_01_VALUE_10', 'FEATURE_02_VALUE_02', 'FEATURE_02_VALUE_03',
#        'FEATURE_02_VALUE_04', 'FEATURE_02_VALUE_06', 'FEATURE_05_VALUE_01',
#        'FEATURE_05_VALUE_02', 'FEATURE_05_VALUE_03', 'FEATURE_05_VALUE_04',
#        'FEATURE_05_VALUE_05', 'FEATURE_05_VALUE_06', 'FEATURE_05_VALUE_07',
#        'FEATURE_05_VALUE_08', 'FEATURE_11_VALUE_01', 'FEATURE_11_VALUE_02',
#        'FEATURE_11_VALUE_03', 'FEATURE_11_VALUE_04', 'FEATURE_11_VALUE_05',
#        'FEATURE_11_VALUE_06', 'FEATURE_11_VALUE_07', 'FEATURE_12_VALUE_01',
#        'FEATURE_12_VALUE_02'],
#       dtype='object')

# %%
features = ['2016_1', '2016_10', '2016_11', '2016_12', '2016_2',
       '2016_3', '2016_4', '2016_5', '2016_6', '2016_7', '2016_8', '2016_9','cod_ap',
       'cod_municipio', 'feature_03', 'feature_04', 'feature_06', 'feature_07',
       'feature_08', 'feature_09', 'feature_10', 'feature_13', 'feature_14',
       'feature_15', 'feature_16', 'feature_17', 'feature_18',
       'FEATURE_01_VALUE_03', 'FEATURE_01_VALUE_06', 'FEATURE_01_VALUE_08',
       'FEATURE_01_VALUE_10', 'FEATURE_02_VALUE_02', 'FEATURE_02_VALUE_03',
       'FEATURE_02_VALUE_04', 'FEATURE_02_VALUE_06', 'FEATURE_05_VALUE_01',
       'FEATURE_05_VALUE_02', 'FEATURE_05_VALUE_03', 'FEATURE_05_VALUE_04',
       'FEATURE_05_VALUE_05', 'FEATURE_05_VALUE_06', 'FEATURE_05_VALUE_07',
       'FEATURE_05_VALUE_08', 'FEATURE_11_VALUE_01', 'FEATURE_11_VALUE_02',
       'FEATURE_11_VALUE_03', 'FEATURE_11_VALUE_04', 'FEATURE_11_VALUE_05',
       'FEATURE_11_VALUE_06', 'FEATURE_11_VALUE_07', 'FEATURE_12_VALUE_01',
       'FEATURE_12_VALUE_02']
X = estatico_faturamento[features]
target = ['2017_1']
Y = estatico_faturamento[target]

# %%
print(X)
# Out:
#          2016_1    2016_10  ...  FEATURE_12_VALUE_01  FEATURE_12_VALUE_02
# 0     441833.37  611797.30  ...                    0                    0
# 1      54660.39   53209.15  ...                    0                    0
# 2     161428.96  198425.47  ...                    0                    0
# 3      54363.21   41540.57  ...                    0                    0
# 4     248834.01  219199.82  ...                    1                    0
# ...         ...        ...  ...                  ...                  ...
# 3082  121727.10  135680.82  ...                    0                    0
# 3083  190014.89  146891.10  ...                    0                    0
# 3084  187775.61  168270.33  ...                    0                    0
# 3085   85259.81   65652.53  ...                    0                    0
# 3086   48988.51   48056.18  ...                    0                    0
#
# [3087 rows x 52 columns]

# %%
print(X.columns.values)
# Out:
# ['2016_1' '2016_10' '2016_11' '2016_12' '2016_2' '2016_3' '2016_4'
#  '2016_5' '2016_6' '2016_7' '2016_8' '2016_9' 'cod_ap' 'cod_municipio'
#  'feature_03' 'feature_04' 'feature_06' 'feature_07' 'feature_08'
#  'feature_09' 'feature_10' 'feature_13' 'feature_14' 'feature_15'
#  'feature_16' 'feature_17' 'feature_18' 'FEATURE_01_VALUE_03'
#  'FEATURE_01_VALUE_06' 'FEATURE_01_VALUE_08' 'FEATURE_01_VALUE_10'
#  'FEATURE_02_VALUE_02' 'FEATURE_02_VALUE_03' 'FEATURE_02_VALUE_04'
#  'FEATURE_02_VALUE_06' 'FEATURE_05_VALUE_01' 'FEATURE_05_VALUE_02'
#  'FEATURE_05_VALUE_03' 'FEATURE_05_VALUE_04' 'FEATURE_05_VALUE_05'
#  'FEATURE_05_VALUE_06' 'FEATURE_05_VALUE_07' 'FEATURE_05_VALUE_08'
#  'FEATURE_11_VALUE_01' 'FEATURE_11_VALUE_02' 'FEATURE_11_VALUE_03'
#  'FEATURE_11_VALUE_04' 'FEATURE_11_VALUE_05' 'FEATURE_11_VALUE_06'
#  'FEATURE_11_VALUE_07' 'FEATURE_12_VALUE_01' 'FEATURE_12_VALUE_02']

# %%
seed = 7
test_size = 0.33
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
model = xgboost.XGBRegressor(objective="reg:squarederror", random_state=42)
score = cross_val_score(model, X_train, y_train, scoring="neg_root_mean_squared_error", cv=5)
display_scores(np.sqrt(-score))
# Out:
# Scores: [118.22040842 126.9666294  147.44993028 125.814051   128.04234847]
# Mean: 129.2986735129092
# Standard deviation: 9.709330110958527

# %%
model = model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mean_squared_error(y_test,y_pred)
# Out:
# 228266247.33194846

# %%
# plot feature importance
fig, ax = plt.subplots(1,1,figsize=(15,15))
plot_importance(model, ax=ax)
plt.show()

# %%
model = xgboost.XGBRegressor(random_state=42)
param_grid = {
    'booster': ['gbtree', 'gblinear', 'dart'],
    'max_depth': list(range(3,20)),
    'n_estimators': list(range(50,1000)),
    'learning_rate': list(np.logspace(np.log10(0.005), np.log10(0.5), base = 10, num = 1000)),
    'gamma': list(range(20000, 300000, 20000)),
    'min_child_samples': list(range(20, 500, 5)),
    'reg_alpha': list(np.linspace(0, 1)),
    'reg_lambda': list(np.linspace(0, 1)),
    'colsample_bytree': list(np.linspace(0.6, 1, 10)),
    'subsample': list(np.linspace(0.5, 1, 100)),
    'objective': ['reg:squarederror'],
}

# %%
features = ['2016_1', '2016_10', '2016_11', '2016_12', '2016_2',
       '2016_3', '2016_4', '2016_5', '2016_6', '2016_7', '2016_8', '2016_9','cod_ap',
       'cod_municipio', 'feature_03', 'feature_04', 'feature_06', 'feature_07',
       'feature_08', 'feature_09', 'feature_10', 'feature_13', 'feature_14',
       'feature_15', 'feature_16', 'feature_17', 'feature_18',
       'FEATURE_01_VALUE_03', 'FEATURE_01_VALUE_06', 'FEATURE_01_VALUE_08',
       'FEATURE_01_VALUE_10', 'FEATURE_02_VALUE_02', 'FEATURE_02_VALUE_03',
       'FEATURE_02_VALUE_04', 'FEATURE_02_VALUE_06', 'FEATURE_05_VALUE_01',
       'FEATURE_05_VALUE_02', 'FEATURE_05_VALUE_03', 'FEATURE_05_VALUE_04',
       'FEATURE_05_VALUE_05', 'FEATURE_05_VALUE_06', 'FEATURE_05_VALUE_07',
       'FEATURE_05_VALUE_08', 'FEATURE_11_VALUE_01', 'FEATURE_11_VALUE_02',
       'FEATURE_11_VALUE_03', 'FEATURE_11_VALUE_04', 'FEATURE_11_VALUE_05',
       'FEATURE_11_VALUE_06', 'FEATURE_11_VALUE_07', 'FEATURE_12_VALUE_01',
       'FEATURE_12_VALUE_02']
X = estatico_faturamento[features]
target = ['2017_1']
Y = estatico_faturamento[target]

# %%
seed = 7
test_size = 0.33
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
print(X.columns)
# Out:
# Index(['2016_1', '2016_10', '2016_11', '2016_12', '2016_2', '2016_3', '2016_4',
#        '2016_5', '2016_6', '2016_7', '2016_8', '2016_9', 'cod_ap',
#        'cod_municipio', 'feature_03', 'feature_04', 'feature_06', 'feature_07',
#        'feature_08', 'feature_09', 'feature_10', 'feature_13', 'feature_14',
#        'feature_15', 'feature_16', 'feature_17', 'feature_18',
#        'FEATURE_01_VALUE_03', 'FEATURE_01_VALUE_06', 'FEATURE_01_VALUE_08',
#        'FEATURE_01_VALUE_10', 'FEATURE_02_VALUE_02', 'FEATURE_02_VALUE_03',
#        'FEATURE_02_VALUE_04', 'FEATURE_02_VALUE_06', 'FEATURE_05_VALUE_01',
#        'FEATURE_05_VALUE_02', 'FEATURE_05_VALUE_03', 'FEATURE_05_VALUE_04',
#        'FEATURE_05_VALUE_05', 'FEATURE_05_VALUE_06', 'FEATURE_05_VALUE_07',
#        'FEATURE_05_VALUE_08', 'FEATURE_11_VALUE_01', 'FEATURE_11_VALUE_02',
#        'FEATURE_11_VALUE_03', 'FEATURE_11_VALUE_04', 'FEATURE_11_VALUE_05',
#        'FEATURE_11_VALUE_06', 'FEATURE_11_VALUE_07', 'FEATURE_12_VALUE_01',
#        'FEATURE_12_VALUE_02'],
#       dtype='object')

# %%
seed = 7
test_size = 0.33
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
clf = RandomizedSearchCV(model, param_grid, random_state=0, n_iter=1000, scoring="neg_root_mean_squared_error", cv=5, verbose=10)
search = clf.fit(X_train, y_train)
print(search.best_params_)
# Out:
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
# [CV] subsample=0.6161616161616161, reg_lambda=0.8571428571428571, reg_alpha=0.6122448979591836, objective=reg:squarederror, n_estimators=606, min_child_samples=380, max_depth=13, learning_rate=0.01634874872255883, gamma=180000, colsample_bytree=0.8666666666666667, booster=gbtree
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  subsample=0.6161616161616161, reg_lambda=0.8571428571428571, reg_alpha=0.6122448979591836, objective=reg:squarederror, n_estimators=606, min_child_samples=380, max_depth=13, learning_rate=0.01634874872255883, gamma=180000, colsample_bytree=0.8666666666666667, booster=gbtree, score=-14669.812, total=  10.3s
# [CV] subsample=0.6161616161616161, reg_lambda=0.8571428571428571, reg_alpha=0.6122448979591836, objective=reg:squarederror, n_estimators=606, min_child_samples=380, max_depth=13, learning_rate=0.01634874872255883, gamma=180000, colsample_bytree=0.8666666666666667, booster=gbtree
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.3s remaining:    0.0s
# [CV]  subsample=0.6161616161616161, reg_lambda=0.8571428571428571, reg_alpha=0.6122448979591836, objective=reg:squarederror, n_estimators=606, min_child_samples=380, max_depth=13, learning_rate=0.01634874872255883, gamma=180000, colsample_bytree=0.8666666666666667, booster=gbtree, score=-15183.073, total=  10.1s
# [CV] subsample=0.6161616161616161, reg_lambda=0.8571428571428571, reg_alpha=0.6122448979591836, objective=reg:squarederror, n_estimators=606, min_child_samples=380, max_depth=13, learning_rate=0.01634874872255883, gamma=180000, colsample_bytree=0.8666666666666667, booster=gbtree
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   20.4s remaining:    0.0s
# [CV]  subsample=0.6161616161616161, reg_lambda=0.8571428571428571, reg_alpha=0.6122448979591836, objective=reg:squarederror, n_estimators=606, min_child_samples=380, max_depth=13, learning_rate=0.01634874872255883, gamma=180000, colsample_bytree=0.8666666666666667, booster=gbtree, score=-21807.940, total=  10.3s
# [CV] subsample=0.6161616161616161, reg_lambda=0.8571428571428571, reg_alpha=0.6122448979591836, objective=reg:squarederror, n_estimators=606, min_child_samples=380, max_depth=13, learning_rate=0.01634874872255883, gamma=180000, colsample_bytree=0.8666666666666667, booster=gbtree
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   30.8s remaining:    0.0s
# [CV]  subsample=0.6161616161616161, reg_lambda=0.8571428571428571, reg_alpha=0.6122448979591836, objective=reg:squarederror, n_estimators=606, min_child_samples=380, max_depth=13, learning_rate=0.01634874872255883, gamma=180000, colsample_bytree=0.8666666666666667, booster=gbtree, score=-15594.514, total=  10.1s
# [CV] subsample=0.6161616161616161, reg_lambda=0.8571428571428571, reg_alpha=0.6122448979591836, objective=reg:squarederror, n_estimators=606, min_child_samples=380, max_depth=13, learning_rate=0.01634874872255883, gamma=180000, colsample_bytree=0.8666666666666667, booster=gbtree
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   40.9s remaining:    0.0s
# [CV]  subsample=0.6161616161616161, reg_lambda=0.8571428571428571, reg_alpha=0.6122448979591836, objective=reg:squarederror, n_estimators=606, min_child_samples=380, max_depth=13, learning_rate=0.01634874872255883, gamma=180000, colsample_bytree=0.8666666666666667, booster=gbtree, score=-16223.444, total=  10.3s
# [CV] subsample=0.5353535353535354, reg_lambda=0.5510204081632653, reg_alpha=0.12244897959183673, objective=reg:squarederror, n_estimators=203, min_child_samples=140, max_depth=11, learning_rate=0.12834513577459752, gamma=20000, colsample_bytree=0.8666666666666667, booster=gbtree
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   51.2s remaining:    0.0s
# [CV]  subsample=0.5353535353535354, reg_lambda=0.5510204081632653, reg_alpha=0.12244897959183673, objective=reg:squarederror, n_estimators=203, min_child_samples=140, max_depth=11, learning_rate=0.12834513577459752, gamma=20000, colsample_bytree=0.8666666666666667, booster=gbtree, score=-14324.429, total=   3.0s
# [CV] subsample=0.5353535353535354, reg_lambda=0.5510204081632653, reg_alpha=0.12244897959183673, objective=reg:squarederror, n_estimators=203, min_child_samples=140, max_depth=11, learning_rate=0.12834513577459752, gamma=20000, colsample_bytree=0.8666666666666667, booster=gbtree
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   54.2s remaining:    0.0s
# [CV]  subsample=0.5353535353535354, reg_lambda=0.5510204081632653, reg_alpha=0.12244897959183673, objective=reg:squarederror, n_estimators=203, min_child_samples=140, max_depth=11, learning_rate=0.12834513577459752, gamma=20000, colsample_bytree=0.8666666666666667, booster=gbtree, score=-16000.023, total=   3.1s
# [CV] subsample=0.5353535353535354, reg_lambda=0.5510204081632653, reg_alpha=0.12244897959183673, objective=reg:squarederror, n_estimators=203, min_child_samples=140, max_depth=11, learning_rate=0.12834513577459752, gamma=20000, colsample_bytree=0.8666666666666667, booster=gbtree
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   57.3s remaining:    0.0s
# [CV]  subsample=0.5353535353535354, reg_lambda=0.5510204081632653, reg_alpha=0.12244897959183673, objective=reg:squarederror, n_estimators=203, min_child_samples=140, max_depth=11, learning_rate=0.12834513577459752, gamma=20000, colsample_bytree=0.8666666666666667, booster=gbtree, score=-22732.257, total=   3.1s
# [CV] subsample=0.5353535353535354, reg_lambda=0.5510204081632653, reg_alpha=0.12244897959183673, objective=reg:squarederror, n_estimators=203, min_child_samples=140, max_depth=11, learning_rate=0.12834513577459752, gamma=20000, colsample_bytree=0.8666666666666667, booster=gbtree
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  1.0min remaining:    0.0s
# [CV]  subsample=0.5353535353535354, reg_lambda=0.5510204081632653, reg_alpha=0.12244897959183673, objective=reg:squarederror, n_estimators=203, min_child_samples=140, max_depth=11, learning_rate=0.12834513577459752, gamma=20000, colsample_bytree=0.8666666666666667, booster=gbtree, score=-16092.965, total=   3.1s
# [CV] subsample=0.5353535353535354, reg_lambda=0.5510204081632653, reg_alpha=0.12244897959183673, objective=reg:squarederror, n_estimators=203, min_child_samples=140, max_depth=11, learning_rate=0.12834513577459752, gamma=20000, colsample_bytree=0.8666666666666667, booster=gbtree
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  1.1min remaining:    0.0s
# [CV]  subsample=0.5353535353535354, reg_lambda=0.5510204081632653, reg_alpha=0.12244897959183673, objective=reg:squarederror, n_estimators=203, min_child_samples=140, max_depth=11, learning_rate=0.12834513577459752, gamma=20000, colsample_bytree=0.8666666666666667, booster=gbtree, score=-18580.749, total=   3.0s
# [CV] subsample=0.7929292929292929, reg_lambda=0.24489795918367346, reg_alpha=1.0, objective=reg:squarederror, n_estimators=908, min_child_samples=25, max_depth=18, learning_rate=0.17238820273672317, gamma=260000, colsample_bytree=0.9111111111111111, booster=gblinear
# [CV]  subsample=0.7929292929292929, reg_lambda=0.24489795918367346, reg_alpha=1.0, objective=reg:squarederror, n_estimators=908, min_child_samples=25, max_depth=18, learning_rate=0.17238820273672317, gamma=260000, colsample_bytree=0.9111111111111111, booster=gblinear, score=-14784.588, total=   0.9s
# [CV] subsample=0.7929292929292929, reg_lambda=0.24489795918367346, reg_alpha=1.0, objective=reg:squarederror, n_estimators=908, min_child_samples=25, max_depth=18, learning_rate=0.17238820273672317, gamma=260000, colsample_bytree=0.9111111111111111, booster=gblinear
# [CV]  subsample=0.7929292929292929, reg_lambda=0.24489795918367346, reg_alpha=1.0, objective=reg:squarederror, n_estimators=908, min_child_samples=25, max_depth=18, learning_rate=0.17238820273672317, gamma=260000, colsample_bytree=0.9111111111111111, booster=gblinear, score=-15451.263, total=   1.0s
# [CV] subsample=0.7929292929292929, reg_lambda=0.24489795918367346, reg_alpha=1.0, objective=reg:squarederror, n_estimators=908, min_child_samples=25, max_depth=18, learning_rate=0.17238820273672317, gamma=260000, colsample_bytree=0.9111111111111111, booster=gblinear
# [CV]  subsample=0.7929292929292929, reg_lambda=0.24489795918367346, reg_alpha=1.0, objective=reg:squarederror, n_estimators=908, min_child_samples=25, max_depth=18, learning_rate=0.17238820273672317, gamma=260000, colsample_bytree=0.9111111111111111, booster=gblinear, score=-23573.636, total=   0.9s
# [CV] subsample=0.7929292929292929, reg_lambda=0.24489795918367346, reg_alpha=1.0, objective=reg:squarederror, n_estimators=908, min_child_samples=25, max_depth=18, learning_rate=0.17238820273672317, gamma=260000, colsample_bytree=0.9111111111111111, booster=gblinear
# [CV]  subsample=0.7929292929292929, reg_lambda=0.24489795918367346, reg_alpha=1.0, objective=reg:squarederror, n_estimators=908, min_child_samples=25, max_depth=18, learning_rate=0.17238820273672317, gamma=260000, colsample_bytree=0.9111111111111111, booster=gblinear, score=-15346.825, total=   1.0s
# [CV] subsample=0.7929292929292929, reg_lambda=0.24489795918367346, reg_alpha=1.0, objective=reg:squarederror, n_estimators=908, min_child_samples=25, max_depth=18, learning_rate=0.17238820273672317, gamma=260000, colsample_bytree=0.9111111111111111, booster=gblinear
# [CV]  subsample=0.7929292929292929, reg_lambda=0.24489795918367346, reg_alpha=1.0, objective=reg:squarederror, n_estimators=908, min_child_samples=25, max_depth=18, learning_rate=0.17238820273672317, gamma=260000, colsample_bytree=0.9111111111111111, booster=gblinear, score=-13440.314, total=   0.9s
# [CV] subsample=0.7171717171717171, reg_lambda=0.061224489795918366, reg_alpha=0.6530612244897959, objective=reg:squarederror, n_estimators=82, min_child_samples=420, max_depth=11, learning_rate=0.009983212250548965, gamma=100000, colsample_bytree=0.6, booster=gbtree
# [CV]  subsample=0.7171717171717171, reg_lambda=0.061224489795918366, reg_alpha=0.6530612244897959, objective=reg:squarederror, n_estimators=82, min_child_samples=420, max_depth=11, learning_rate=0.009983212250548965, gamma=100000, colsample_bytree=0.6, booster=gbtree, score=-61010.372, total=   0.9s
# [CV] subsample=0.7171717171717171, reg_lambda=0.061224489795918366, reg_alpha=0.6530612244897959, objective=reg:squarederror, n_estimators=82, min_child_samples=420, max_depth=11, learning_rate=0.009983212250548965, gamma=100000, colsample_bytree=0.6, booster=gbtree
# [CV]  subsample=0.7171717171717171, reg_lambda=0.061224489795918366, reg_alpha=0.6530612244897959, objective=reg:squarederror, n_estimators=82, min_child_samples=420, max_depth=11, learning_rate=0.009983212250548965, gamma=100000, colsample_bytree=0.6, booster=gbtree, score=-61488.666, total=   0.9s
# [CV] subsample=0.7171717171717171, reg_lambda=0.061224489795918366, reg_alpha=0.6530612244897959, objective=reg:squarederror, n_estimators=82, min_child_samples=420, max_depth=11, learning_rate=0.009983212250548965, gamma=100000, colsample_bytree=0.6, booster=gbtree
# [CV]  subsample=0.7171717171717171, reg_lambda=0.061224489795918366, reg_alpha=0.6530612244897959, objective=reg:squarederror, n_estimators=82, min_child_samples=420, max_depth=11, learning_rate=0.009983212250548965, gamma=100000, colsample_bytree=0.6, booster=gbtree, score=-63208.473, total=   0.9s
# [CV] subsample=0.7171717171717171, reg_lambda=0.061224489795918366, reg_alpha=0.6530612244897959, objective=reg:squarederror, n_estimators=82, min_child_samples=420, max_depth=11, learning_rate=0.009983212250548965, gamma=100000, colsample_bytree=0.6, booster=gbtree
# [CV]  subsample=0.7171717171717171, reg_lambda=0.061224489795918366, reg_alpha=0.6530612244897959, objective=reg:squarederror, n_estimators=82, min_child_samples=420, max_depth=11, learning_rate=0.009983212250548965, gamma=100000, colsample_bytree=0.6, booster=gbtree, score=-60349.105, total=   0.9s
# [CV] subsample=0.7171717171717171, reg_lambda=0.061224489795918366, reg_alpha=0.6530612244897959, objective=reg:squarederror, n_estimators=82, min_child_samples=420, max_depth=11, learning_rate=0.009983212250548965, gamma=100000, colsample_bytree=0.6, booster=gbtree
# [CV]  subsample=0.7171717171717171, reg_lambda=0.061224489795918366, reg_alpha=0.6530612244897959, objective=reg:squarederror, n_estimators=82, min_child_samples=420, max_depth=11, learning_rate=0.009983212250548965, gamma=100000, colsample_bytree=0.6, booster=gbtree, score=-59600.027, total=   0.9s
# [CV] subsample=0.7828282828282829, reg_lambda=0.36734693877551017, reg_alpha=0.02040816326530612, objective=reg:squarederror, n_estimators=69, min_child_samples=105, max_depth=19, learning_rate=0.09337729213805379, gamma=260000, colsample_bytree=0.7333333333333333, booster=gbtree
# [CV]  subsample=0.7828282828282829, reg_lambda=0.36734693877551017, reg_alpha=0.02040816326530612, objective=reg:squarederror, n_estimators=69, min_child_samples=105, max_depth=19, learning_rate=0.09337729213805379, gamma=260000, colsample_bytree=0.7333333333333333, booster=gbtree, score=-14955.193, total=   1.4s
# [CV] subsample=0.7828282828282829, reg_lambda=0.36734693877551017, reg_alpha=0.02040816326530612, objective=reg:squarederror, n_estimators=69, min_child_samples=105, max_depth=19, learning_rate=0.09337729213805379, gamma=260000, colsample_bytree=0.7333333333333333, booster=gbtree
# [CV]  subsample=0.7828282828282829, reg_lambda=0.36734693877551017, reg_alpha=0.02040816326530612, objective=reg:squarederror, n_estimators=69, min_child_samples=105, max_depth=19, learning_rate=0.09337729213805379, gamma=260000, colsample_bytree=0.7333333333333333, booster=gbtree, score=-15875.164, total=   1.4s
# [CV] subsample=0.7828282828282829, reg_lambda=0.36734693877551017, reg_alpha=0.02040816326530612, objective=reg:squarederror, n_estimators=69, min_child_samples=105, max_depth=19, learning_rate=0.09337729213805379, gamma=260000, colsample_bytree=0.7333333333333333, booster=gbtree
# [CV]  subsample=0.7828282828282829, reg_lambda=0.36734693877551017, reg_alpha=0.02040816326530612, objective=reg:squarederror, n_estimators=69, min_child_samples=105, max_depth=19, learning_rate=0.09337729213805379, gamma=260000, colsample_bytree=0.7333333333333333, booster=gbtree, score=-22745.808, total=   1.4s
# [CV] subsample=0.7828282828282829, reg_lambda=0.36734693877551017, reg_alpha=0.02040816326530612, objective=reg:squarederror, n_estimators=69, min_child_samples=105, max_depth=19, learning_rate=0.09337729213805379, gamma=260000, colsample_bytree=0.7333333333333333, booster=gbtree
# [CV]  subsample=0.7828282828282829, reg_lambda=0.36734693877551017, reg_alpha=0.02040816326530612, objective=reg:squarederror, n_estimators=69, min_child_samples=105, max_depth=19, learning_rate=0.09337729213805379, gamma=260000, colsample_bytree=0.7333333333333333, booster=gbtree, score=-15705.406, total=   1.3s
# [CV] subsample=0.7828282828282829, reg_lambda=0.36734693877551017, reg_alpha=0.02040816326530612, objective=reg:squarederror, n_estimators=69, min_child_samples=105, max_depth=19, learning_rate=0.09337729213805379, gamma=260000, colsample_bytree=0.7333333333333333, booster=gbtree
# [CV]  subsample=0.7828282828282829, reg_lambda=0.36734693877551017, reg_alpha=0.02040816326530612, objective=reg:squarederror, n_estimators=69, min_child_samples=105, max_depth=19, learning_rate=0.09337729213805379, gamma=260000, colsample_bytree=0.7333333333333333, booster=gbtree, score=-16013.092, total=   1.4s
# [CV] subsample=0.5050505050505051, reg_lambda=0.04081632653061224, reg_alpha=0.7551020408163265, objective=reg:squarederror, n_estimators=873, min_child_samples=265, max_depth=15, learning_rate=0.1586614817367488, gamma=200000, colsample_bytree=0.9555555555555555, booster=dart
# [CV]  subsample=0.5050505050505051, reg_lambda=0.04081632653061224, reg_alpha=0.7551020408163265, objective=reg:squarederror, n_estimators=873, min_child_samples=265, max_depth=15, learning_rate=0.1586614817367488, gamma=200000, colsample_bytree=0.9555555555555555, booster=dart, score=-15317.990, total= 1.0min
# [CV] subsample=0.5050505050505051, reg_lambda=0.04081632653061224, reg_alpha=0.7551020408163265, objective=reg:squarederror, n_estimators=873, min_child_samples=265, max_depth=15, learning_rate=0.1586614817367488, gamma=200000, colsample_bytree=0.9555555555555555, booster=dart
# [CV]  subsample=0.5050505050505051, reg_lambda=0.04081632653061224, reg_alpha=0.7551020408163265, objective=reg:squarederror, n_estimators=873, min_child_samples=265, max_depth=15, learning_rate=0.1586614817367488, gamma=200000, colsample_bytree=0.9555555555555555, booster=dart, score=-16932.068, total= 1.0min
# [CV] subsample=0.5050505050505051, reg_lambda=0.04081632653061224, reg_alpha=0.7551020408163265, objective=reg:squarederror, n_estimators=873, min_child_samples=265, max_depth=15, learning_rate=0.1586614817367488, gamma=200000, colsample_bytree=0.9555555555555555, booster=dart
# [CV]  subsample=0.5050505050505051, reg_lambda=0.04081632653061224, reg_alpha=0.7551020408163265, objective=reg:squarederror, n_estimators=873, min_child_samples=265, max_depth=15, learning_rate=0.1586614817367488, gamma=200000, colsample_bytree=0.9555555555555555, booster=dart, score=-22183.950, total= 1.0min
# [CV] subsample=0.5050505050505051, reg_lambda=0.04081632653061224, reg_alpha=0.7551020408163265, objective=reg:squarederror, n_estimators=873, min_child_samples=265, max_depth=15, learning_rate=0.1586614817367488, gamma=200000, colsample_bytree=0.9555555555555555, booster=dart
# [CV]  subsample=0.5050505050505051, reg_lambda=0.04081632653061224, reg_alpha=0.7551020408163265, objective=reg:squarederror, n_estimators=873, min_child_samples=265, max_depth=15, learning_rate=0.1586614817367488, gamma=200000, colsample_bytree=0.9555555555555555, booster=dart, score=-17266.247, total= 1.1min
# [CV] subsample=0.5050505050505051, reg_lambda=0.04081632653061224, reg_alpha=0.7551020408163265, objective=reg:squarederror, n_estimators=873, min_child_samples=265, max_depth=15, learning_rate=0.1586614817367488, gamma=200000, colsample_bytree=0.9555555555555555, booster=dart
# [CV]  subsample=0.5050505050505051, reg_lambda=0.04081632653061224, reg_alpha=0.7551020408163265, objective=reg:squarederror, n_estimators=873, min_child_samples=265, max_depth=15, learning_rate=0.1586614817367488, gamma=200000, colsample_bytree=0.9555555555555555, booster=dart, score=-19702.893, total= 1.0min
# [CV] subsample=0.8080808080808082, reg_lambda=0.7959183673469387, reg_alpha=0.3877551020408163, objective=reg:squarederror, n_estimators=832, min_child_samples=325, max_depth=4, learning_rate=0.2862383119851089, gamma=240000, colsample_bytree=0.9555555555555555, booster=gblinear
# [CV]  subsample=0.8080808080808082, reg_lambda=0.7959183673469387, reg_alpha=0.3877551020408163, objective=reg:squarederror, n_estimators=832, min_child_samples=325, max_depth=4, learning_rate=0.2862383119851089, gamma=240000, colsample_bytree=0.9555555555555555, booster=gblinear, score=-14812.350, total=   0.8s
# [CV] subsample=0.8080808080808082, reg_lambda=0.7959183673469387, reg_alpha=0.3877551020408163, objective=reg:squarederror, n_estimators=832, min_child_samples=325, max_depth=4, learning_rate=0.2862383119851089, gamma=240000, colsample_bytree=0.9555555555555555, booster=gblinear
# [CV]  subsample=0.8080808080808082, reg_lambda=0.7959183673469387, reg_alpha=0.3877551020408163, objective=reg:squarederror, n_estimators=832, min_child_samples=325, max_depth=4, learning_rate=0.2862383119851089, gamma=240000, colsample_bytree=0.9555555555555555, booster=gblinear, score=-15649.981, total=   0.9s
# [CV] subsample=0.8080808080808082, reg_lambda=0.7959183673469387, reg_alpha=0.3877551020408163, objective=reg:squarederror, n_estimators=832, min_child_samples=325, max_depth=4, learning_rate=0.2862383119851089, gamma=240000, colsample_bytree=0.9555555555555555, booster=gblinear
# [CV]  subsample=0.8080808080808082, reg_lambda=0.7959183673469387, reg_alpha=0.3877551020408163, objective=reg:squarederror, n_estimators=832, min_child_samples=325, max_depth=4, learning_rate=0.2862383119851089, gamma=240000, colsample_bytree=0.9555555555555555, booster=gblinear, score=-23640.201, total=   0.8s
# [CV] subsample=0.8080808080808082, reg_lambda=0.7959183673469387, reg_alpha=0.3877551020408163, objective=reg:squarederror, n_estimators=832, min_child_samples=325, max_depth=4, learning_rate=0.2862383119851089, gamma=240000, colsample_bytree=0.9555555555555555, booster=gblinear
# [CV]  subsample=0.8080808080808082, reg_lambda=0.7959183673469387, reg_alpha=0.3877551020408163, objective=reg:squarederror, n_estimators=832, min_child_samples=325, max_depth=4, learning_rate=0.2862383119851089, gamma=240000, colsample_bytree=0.9555555555555555, booster=gblinear, score=-15448.033, total=   0.9s
# [CV] subsample=0.8080808080808082, reg_lambda=0.7959183673469387, reg_alpha=0.3877551020408163, objective=reg:squarederror, n_estimators=832, min_child_samples=325, max_depth=4, learning_rate=0.2862383119851089, gamma=240000, colsample_bytree=0.9555555555555555, booster=gblinear
# [CV]  subsample=0.8080808080808082, reg_lambda=0.7959183673469387, reg_alpha=0.3877551020408163, objective=reg:squarederror, n_estimators=832, min_child_samples=325, max_depth=4, learning_rate=0.2862383119851089, gamma=240000, colsample_bytree=0.9555555555555555, booster=gblinear, score=-13680.758, total=   0.8s
# [CV] subsample=0.98989898989899, reg_lambda=0.5306122448979591, reg_alpha=0.44897959183673464, objective=reg:squarederror, n_estimators=802, min_child_samples=245, max_depth=16, learning_rate=0.008693812001081252, gamma=200000, colsample_bytree=0.6888888888888889, booster=gblinear
# [CV]  subsample=0.98989898989899, reg_lambda=0.5306122448979591, reg_alpha=0.44897959183673464, objective=reg:squarederror, n_estimators=802, min_child_samples=245, max_depth=16, learning_rate=0.008693812001081252, gamma=200000, colsample_bytree=0.6888888888888889, booster=gblinear, score=-19785.422, total=   0.9s
# [CV] subsample=0.98989898989899, reg_lambda=0.5306122448979591, reg_alpha=0.44897959183673464, objective=reg:squarederror, n_estimators=802, min_child_samples=245, max_depth=16, learning_rate=0.008693812001081252, gamma=200000, colsample_bytree=0.6888888888888889, booster=gblinear
# [CV]  subsample=0.98989898989899, reg_lambda=0.5306122448979591, reg_alpha=0.44897959183673464, objective=reg:squarederror, n_estimators=802, min_child_samples=245, max_depth=16, learning_rate=0.008693812001081252, gamma=200000, colsample_bytree=0.6888888888888889, booster=gblinear, score=-17954.027, total=   0.8s
# [CV] subsample=0.98989898989899, reg_lambda=0.5306122448979591, reg_alpha=0.44897959183673464, objective=reg:squarederror, n_estimators=802, min_child_samples=245, max_depth=16, learning_rate=0.008693812001081252, gamma=200000, colsample_bytree=0.6888888888888889, booster=gblinear
# [CV]  subsample=0.98989898989899, reg_lambda=0.5306122448979591, reg_alpha=0.44897959183673464, objective=reg:squarederror, n_estimators=802, min_child_samples=245, max_depth=16, learning_rate=0.008693812001081252, gamma=200000, colsample_bytree=0.6888888888888889, booster=gblinear, score=-25827.736, total=   0.8s
# [CV] subsample=0.98989898989899, reg_lambda=0.5306122448979591, reg_alpha=0.44897959183673464, objective=reg:squarederror, n_estimators=802, min_child_samples=245, max_depth=16, learning_rate=0.008693812001081252, gamma=200000, colsample_bytree=0.6888888888888889, booster=gblinear
# [CV]  subsample=0.98989898989899, reg_lambda=0.5306122448979591, reg_alpha=0.44897959183673464, objective=reg:squarederror, n_estimators=802, min_child_samples=245, max_depth=16, learning_rate=0.008693812001081252, gamma=200000, colsample_bytree=0.6888888888888889, booster=gblinear, score=-16814.389, total=   0.8s
# [CV] subsample=0.98989898989899, reg_lambda=0.5306122448979591, reg_alpha=0.44897959183673464, objective=reg:squarederror, n_estimators=802, min_child_samples=245, max_depth=16, learning_rate=0.008693812001081252, gamma=200000, colsample_bytree=0.6888888888888889, booster=gblinear
# [CV]  subsample=0.98989898989899, reg_lambda=0.5306122448979591, reg_alpha=0.44897959183673464, objective=reg:squarederror, n_estimators=802, min_child_samples=245, max_depth=16, learning_rate=0.008693812001081252, gamma=200000, colsample_bytree=0.6888888888888889, booster=gblinear, score=-14371.793, total=   0.8s
# [CV] subsample=0.5404040404040404, reg_lambda=0.2040816326530612, reg_alpha=0.061224489795918366, objective=reg:squarederror, n_estimators=848, min_child_samples=325, max_depth=19, learning_rate=0.015756817424332395, gamma=20000, colsample_bytree=1.0, booster=dart
# [CV]  subsample=0.5404040404040404, reg_lambda=0.2040816326530612, reg_alpha=0.061224489795918366, objective=reg:squarederror, n_estimators=848, min_child_samples=325, max_depth=19, learning_rate=0.015756817424332395, gamma=20000, colsample_bytree=1.0, booster=dart, score=-13968.750, total= 3.9min
# [CV] subsample=0.5404040404040404, reg_lambda=0.2040816326530612, reg_alpha=0.061224489795918366, objective=reg:squarederror, n_estimators=848, min_child_samples=325, max_depth=19, learning_rate=0.015756817424332395, gamma=20000, colsample_bytree=1.0, booster=dart
# [CV]  subsample=0.5404040404040404, reg_lambda=0.2040816326530612, reg_alpha=0.061224489795918366, objective=reg:squarederror, n_estimators=848, min_child_samples=325, max_depth=19, learning_rate=0.015756817424332395, gamma=20000, colsample_bytree=1.0, booster=dart, score=-15501.401, total= 4.1min
# [CV] subsample=0.5404040404040404, reg_lambda=0.2040816326530612, reg_alpha=0.061224489795918366, objective=reg:squarederror, n_estimators=848, min_child_samples=325, max_depth=19, learning_rate=0.015756817424332395, gamma=20000, colsample_bytree=1.0, booster=dart
# [CV]  subsample=0.5404040404040404, reg_lambda=0.2040816326530612, reg_alpha=0.061224489795918366, objective=reg:squarederror, n_estimators=848, min_child_samples=325, max_depth=19, learning_rate=0.015756817424332395, gamma=20000, colsample_bytree=1.0, booster=dart, score=-21762.355, total= 4.1min
# [CV] subsample=0.5404040404040404, reg_lambda=0.2040816326530612, reg_alpha=0.061224489795918366, objective=reg:squarederror, n_estimators=848, min_child_samples=325, max_depth=19, learning_rate=0.015756817424332395, gamma=20000, colsample_bytree=1.0, booster=dart
# [CV]  subsample=0.5404040404040404, reg_lambda=0.2040816326530612, reg_alpha=0.061224489795918366, objective=reg:squarederror, n_estimators=848, min_child_samples=325, max_depth=19, learning_rate=0.015756817424332395, gamma=20000, colsample_bytree=1.0, booster=dart, score=-16031.286, total= 4.1min
# [CV] subsample=0.5404040404040404, reg_lambda=0.2040816326530612, reg_alpha=0.061224489795918366, objective=reg:squarederror, n_estimators=848, min_child_samples=325, max_depth=19, learning_rate=0.015756817424332395, gamma=20000, colsample_bytree=1.0, booster=dart
# [CV]  subsample=0.5404040404040404, reg_lambda=0.2040816326530612, reg_alpha=0.061224489795918366, objective=reg:squarederror, n_estimators=848, min_child_samples=325, max_depth=19, learning_rate=0.015756817424332395, gamma=20000, colsample_bytree=1.0, booster=dart, score=-16943.783, total= 4.2min
# [CV] subsample=0.8232323232323233, reg_lambda=0.8163265306122448, reg_alpha=0.0, objective=reg:squarederror, n_estimators=343, min_child_samples=35, max_depth=4, learning_rate=0.08321300882429516, gamma=180000, colsample_bytree=0.8222222222222222, booster=gblinear
# [CV]  subsample=0.8232323232323233, reg_lambda=0.8163265306122448, reg_alpha=0.0, objective=reg:squarederror, n_estimators=343, min_child_samples=35, max_depth=4, learning_rate=0.08321300882429516, gamma=180000, colsample_bytree=0.8222222222222222, booster=gblinear, score=-16542.724, total=   0.4s
# [CV] subsample=0.8232323232323233, reg_lambda=0.8163265306122448, reg_alpha=0.0, objective=reg:squarederror, n_estimators=343, min_child_samples=35, max_depth=4, learning_rate=0.08321300882429516, gamma=180000, colsample_bytree=0.8222222222222222, booster=gblinear
# [CV]  subsample=0.8232323232323233, reg_lambda=0.8163265306122448, reg_alpha=0.0, objective=reg:squarederror, n_estimators=343, min_child_samples=35, max_depth=4, learning_rate=0.08321300882429516, gamma=180000, colsample_bytree=0.8222222222222222, booster=gblinear, score=-15996.595, total=   0.4s
# [CV] subsample=0.8232323232323233, reg_lambda=0.8163265306122448, reg_alpha=0.0, objective=reg:squarederror, n_estimators=343, min_child_samples=35, max_depth=4, learning_rate=0.08321300882429516, gamma=180000, colsample_bytree=0.8222222222222222, booster=gblinear
# [CV]  subsample=0.8232323232323233, reg_lambda=0.8163265306122448, reg_alpha=0.0, objective=reg:squarederror, n_estimators=343, min_child_samples=35, max_depth=4, learning_rate=0.08321300882429516, gamma=180000, colsample_bytree=0.8222222222222222, booster=gblinear, score=-24513.870, total=   0.4s
# [CV] subsample=0.8232323232323233, reg_lambda=0.8163265306122448, reg_alpha=0.0, objective=reg:squarederror, n_estimators=343, min_child_samples=35, max_depth=4, learning_rate=0.08321300882429516, gamma=180000, colsample_bytree=0.8222222222222222, booster=gblinear
# [CV]  subsample=0.8232323232323233, reg_lambda=0.8163265306122448, reg_alpha=0.0, objective=reg:squarederror, n_estimators=343, min_child_samples=35, max_depth=4, learning_rate=0.08321300882429516, gamma=180000, colsample_bytree=0.8222222222222222, booster=gblinear, score=-16046.001, total=   0.4s
# [CV] subsample=0.8232323232323233, reg_lambda=0.8163265306122448, reg_alpha=0.0, objective=reg:squarederror, n_estimators=343, min_child_samples=35, max_depth=4, learning_rate=0.08321300882429516, gamma=180000, colsample_bytree=0.8222222222222222, booster=gblinear
# [CV]  subsample=0.8232323232323233, reg_lambda=0.8163265306122448, reg_alpha=0.0, objective=reg:squarederror, n_estimators=343, min_child_samples=35, max_depth=4, learning_rate=0.08321300882429516, gamma=180000, colsample_bytree=0.8222222222222222, booster=gblinear, score=-13569.572, total=   0.4s
# [CV] subsample=0.8686868686868687, reg_lambda=0.22448979591836732, reg_alpha=0.36734693877551017, objective=reg:squarederror, n_estimators=304, min_child_samples=230, max_depth=12, learning_rate=0.3457879414369262, gamma=80000, colsample_bytree=0.8222222222222222, booster=gblinear
# [CV]  subsample=0.8686868686868687, reg_lambda=0.22448979591836732, reg_alpha=0.36734693877551017, objective=reg:squarederror, n_estimators=304, min_child_samples=230, max_depth=12, learning_rate=0.3457879414369262, gamma=80000, colsample_bytree=0.8222222222222222, booster=gblinear, score=-14678.601, total=   0.3s
# [CV] subsample=0.8686868686868687, reg_lambda=0.22448979591836732, reg_alpha=0.36734693877551017, objective=reg:squarederror, n_estimators=304, min_child_samples=230, max_depth=12, learning_rate=0.3457879414369262, gamma=80000, colsample_bytree=0.8222222222222222, booster=gblinear
# [CV]  subsample=0.8686868686868687, reg_lambda=0.22448979591836732, reg_alpha=0.36734693877551017, objective=reg:squarederror, n_estimators=304, min_child_samples=230, max_depth=12, learning_rate=0.3457879414369262, gamma=80000, colsample_bytree=0.8222222222222222, booster=gblinear, score=-15443.670, total=   0.3s
# [CV] subsample=0.8686868686868687, reg_lambda=0.22448979591836732, reg_alpha=0.36734693877551017, objective=reg:squarederror, n_estimators=304, min_child_samples=230, max_depth=12, learning_rate=0.3457879414369262, gamma=80000, colsample_bytree=0.8222222222222222, booster=gblinear
# [CV]  subsample=0.8686868686868687, reg_lambda=0.22448979591836732, reg_alpha=0.36734693877551017, objective=reg:squarederror, n_estimators=304, min_child_samples=230, max_depth=12, learning_rate=0.3457879414369262, gamma=80000, colsample_bytree=0.8222222222222222, booster=gblinear, score=-23564.845, total=   0.3s
# [CV] subsample=0.8686868686868687, reg_lambda=0.22448979591836732, reg_alpha=0.36734693877551017, objective=reg:squarederror, n_estimators=304, min_child_samples=230, max_depth=12, learning_rate=0.3457879414369262, gamma=80000, colsample_bytree=0.8222222222222222, booster=gblinear
# [CV]  subsample=0.8686868686868687, reg_lambda=0.22448979591836732, reg_alpha=0.36734693877551017, objective=reg:squarederror, n_estimators=304, min_child_samples=230, max_depth=12, learning_rate=0.3457879414369262, gamma=80000, colsample_bytree=0.8222222222222222, booster=gblinear, score=-15337.929, total=   0.3s
# [CV] subsample=0.8686868686868687, reg_lambda=0.22448979591836732, reg_alpha=0.36734693877551017, objective=reg:squarederror, n_estimators=304, min_child_samples=230, max_depth=12, learning_rate=0.3457879414369262, gamma=80000, colsample_bytree=0.8222222222222222, booster=gblinear
# [CV]  subsample=0.8686868686868687, reg_lambda=0.22448979591836732, reg_alpha=0.36734693877551017, objective=reg:squarederror, n_estimators=304, min_child_samples=230, max_depth=12, learning_rate=0.3457879414369262, gamma=80000, colsample_bytree=0.8222222222222222, booster=gblinear, score=-13494.647, total=   0.3s
# [CV] subsample=0.8080808080808082, reg_lambda=0.5510204081632653, reg_alpha=0.18367346938775508, objective=reg:squarederror, n_estimators=648, min_child_samples=470, max_depth=17, learning_rate=0.11437454086778513, gamma=220000, colsample_bytree=0.9111111111111111, booster=gbtree
# [CV]  subsample=0.8080808080808082, reg_lambda=0.5510204081632653, reg_alpha=0.18367346938775508, objective=reg:squarederror, n_estimators=648, min_child_samples=470, max_depth=17, learning_rate=0.11437454086778513, gamma=220000, colsample_bytree=0.9111111111111111, booster=gbtree, score=-15329.160, total=  15.7s
# [CV] subsample=0.8080808080808082, reg_lambda=0.5510204081632653, reg_alpha=0.18367346938775508, objective=reg:squarederror, n_estimators=648, min_child_samples=470, max_depth=17, learning_rate=0.11437454086778513, gamma=220000, colsample_bytree=0.9111111111111111, booster=gbtree
# [CV]  subsample=0.8080808080808082, reg_lambda=0.5510204081632653, reg_alpha=0.18367346938775508, objective=reg:squarederror, n_estimators=648, min_child_samples=470, max_depth=17, learning_rate=0.11437454086778513, gamma=220000, colsample_bytree=0.9111111111111111, booster=gbtree, score=-15658.488, total=  15.6s
# [CV] subsample=0.8080808080808082, reg_lambda=0.5510204081632653, reg_alpha=0.18367346938775508, objective=reg:squarederror, n_estimators=648, min_child_samples=470, max_depth=17, learning_rate=0.11437454086778513, gamma=220000, colsample_bytree=0.9111111111111111, booster=gbtree
# [CV]  subsample=0.8080808080808082, reg_lambda=0.5510204081632653, reg_alpha=0.18367346938775508, objective=reg:squarederror, n_estimators=648, min_child_samples=470, max_depth=17, learning_rate=0.11437454086778513, gamma=220000, colsample_bytree=0.9111111111111111, booster=gbtree, score=-22391.351, total=  15.9s
# [CV] subsample=0.8080808080808082, reg_lambda=0.5510204081632653, reg_alpha=0.18367346938775508, objective=reg:squarederror, n_estimators=648, min_child_samples=470, max_depth=17, learning_rate=0.11437454086778513, gamma=220000, colsample_bytree=0.9111111111111111, booster=gbtree
